# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from random import randint

sys.path.append("/home/dimi/Programming/MachineLearningUFABC/Projeto_Perceptron_Adaline/LMS/python/")
sys.path.append("/home/dimi/Programming/MachineLearningUFABC/Projeto_Perceptron_Adaline/Adaline/python/")
from LMSClass import LMS
from AdalineClass import Adaline

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [10, 5], 
          'figure.titlesize': 16,
          'axes.labelsize': 12,
          'axes.titlesize':14, 
          'font.size': 12,
          'legend.fontsize': 12, 
          'xtick.labelsize': 10, 
          'ytick.labelsize': 10
         }
plt.rcParams.update(params)

# %%
for i in range(3):

    # COEFICIENTES DA RETA ALEATORIOS
    coeficienteAngular = randint(-5,5)
    coeficienteLinear  = randint(-5,5)
    print("Pesos Reais:", [coeficienteLinear, coeficienteAngular])

    # CRIANDO O DATASET COM QUANTIDADE E RANGE DE PONTOS ALEATORIOS
    x = np.linspace(-randint(50,100), randint(50,100), randint(25,75))
    y = []
    for entradaAtual in x:
        y.append(coeficienteAngular*(entradaAtual + randint(-20,20)) + coeficienteLinear)
    y = np.array(y)

    # USANDO A CLASSE IMPLEMENTADA
    objLMS = LMS(x, y)
    
    print("Pesos calculados:", objLMS.pesos)
    print("MSE:", objLMS.MSE)
    print("RMSE:", objLMS.RMSE)

    # PLOTANDO
    eixoXRetaLMS, eixoYRetaLMS = objLMS.obterEixosParaPlotarRetaLMS(x)
    plt.scatter(x, y, s=10)
    plt.plot(eixoXRetaLMS, eixoYRetaLMS, color="tab:brown")
    plt.grid(alpha=0.5)
    plt.xlim(-105, 105)
    plt.ylim(-510, 510)
    plt.show()
# Out:
# Pesos Reais: [4, 3]
# Pesos calculados: [7.35986762 3.10195403]
# MSE: 1327.4149926133023
# RMSE: 36.43370681955519
# Pesos Reais: [-3, 1]
# Pesos calculados: [-4.16069356  0.92649935]
# MSE: 137.81289250317414
# RMSE: 11.739373599267303
# Pesos Reais: [2, 5]
# Pesos calculados: [4.37111181 4.98582004]
# MSE: 4025.8343824720646
# RMSE: 63.44946321657942
# Pesos Reais: [1, 3]
# Pesos calculados: [5.26381558 2.94968203]
# MSE: 1082.1342079231692
# RMSE: 32.89580836403278
# Pesos Reais: [-4, 3]
# Pesos calculados: [-9.26457757  2.98549923]
# MSE: 1215.004883671624
# RMSE: 34.85692016905142
# Pesos Reais: [5, -1]
# Pesos calculados: [ 2.48869514 -1.00595176]
# MSE: 150.97365965854718
# RMSE: 12.287133907406853
# Pesos Reais: [-5, -3]
# Pesos calculados: [-14.61726735  -3.0732114 ]
# MSE: 1262.3949692485105
# RMSE: 35.53019799056164
# Pesos Reais: [-3, -1]
# Pesos calculados: [-3.73609907 -0.98637771]
# MSE: 124.31515523944996
# RMSE: 11.149670633675685
# Pesos Reais: [1, 4]
# Pesos calculados: [-0.45373712  4.12888113]
# MSE: 2044.4958897404063
# RMSE: 45.21610210688672
# Pesos Reais: [-2, -5]
# Pesos calculados: [ 4.51952223 -4.7708839 ]
# MSE: 3487.56014427302
# RMSE: 59.055568274913924
