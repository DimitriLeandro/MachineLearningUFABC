# %% [markdown]
# # Algoritmo para aumentar o SESA para o projeto final de ML

# %% [markdown]
# ### Parâmetros Iniciais (só precisa mudar essa parte)

# %% [markdown]
# ATENÇÃO!
#
# Não precisa criar os diretórios de destino pq o algoritmo cria sozinho caso eles ainda não existam. ENTRETANTO, caso os diretórios de DESTINO já existam, o algoritmo vai apagar tudo que tem lá antes de continuar. C U I D A D O.

# %% [markdown]
# Defina os diretórios de origem e destino dos áudios.

# %%
diretorioOrigemTreinamento  = "/home/dimi/Downloads/Datasets/SESA/SESA_Original/train/"
diretorioDestinoTreinamento = "/home/dimi/Downloads/Datasets/SESA/SESA_Projeto_Final_ML/train/"

diretorioOrigemTeste        = "/home/dimi/Downloads/Datasets/SESA/SESA_Original/test/"
diretorioDestinoTeste       = "/home/dimi/Downloads/Datasets/SESA/SESA_Projeto_Final_ML/test/"

# %% [markdown]
# ### Importações

# %%
import librosa
import sys
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
from joblib import Parallel, delayed

sys.path.append("../python/")
import efeitos

# %%
#DEFININDO ALGUNS PARÂMETROS PARA PLOTAR GRÁFICOS
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [10, 5], 
          'axes.labelsize': 13,
          'axes.titlesize':17, 
          'font.size': 13,
          'legend.fontsize': 13, 
          'xtick.labelsize': 11, 
          'ytick.labelsize': 11
         }
plt.rcParams.update(params)

# %% [markdown]
# ### Verificando se os diretórios de destino já existem

# %%
if os.path.isdir(diretorioDestinoTreinamento) == True:
    shutil.rmtree(diretorioDestinoTreinamento)
if os.path.isdir(diretorioDestinoTeste) == True:
    shutil.rmtree(diretorioDestinoTeste)
    
os.makedirs(diretorioDestinoTreinamento)
os.makedirs(diretorioDestinoTeste)

# %% [markdown]
# ### Função que aplica os efeitos em um único áudio e salva na pasta de destino

# %% [markdown]
# Essa função pega um único áudio do diretório de origem e salva cinco áudios na pasta de destino:
#
# 1) O próprio áudio original
#
# 2) O resultado com velocidade de reprodução alterada
#
# 3) O resultado com pitch shift
#
# 4)  O resultado com deslocamento temporal
#
# 5) O resultado com adição de ruído branco

# %%
def aumentarDataset(nomeAudio, diretorioOrigem, diretorioDestino):
    
    # ABRINDO O AUDIO
    sinalOriginal, freqAmostragem = librosa.core.load(diretorioOrigem + nomeAudio, sr=None, mono=True)
    
    # NORMALIZANDO PELA ENERGIA
    sinalOriginal = efeitos.normalizarEnergia(sinalOriginal)
    
    # APLICANDO OS EFEITOS
    sinalVelocidade, velocidade = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
    sinalRuido, snr             = efeitos.adicionarRuidoBrancoAleatoriamente(sinalOriginal)
    sinalPitch, pitch           = efeitos.mudarPitchAleatoriamente(sinalOriginal, freqAmostragem)
    sinalTempo, tempo           = efeitos.deslocarTempoAleatoriamente(sinalOriginal)
    
    # SALVANDO NO DESTINO (TEM QUE SALVAR O ORIGINAL TB)
    librosa.output.write_wav(diretorioDestino + nomeAudio[:-4] + "_original.wav", sinalOriginal, freqAmostragem)
    librosa.output.write_wav(diretorioDestino + nomeAudio[:-4] + "_velocidade.wav", sinalVelocidade, freqAmostragem)
    librosa.output.write_wav(diretorioDestino + nomeAudio[:-4] + "_ruido.wav", sinalRuido, freqAmostragem)
    librosa.output.write_wav(diretorioDestino + nomeAudio[:-4] + "_pitch.wav", sinalPitch, freqAmostragem)
    librosa.output.write_wav(diretorioDestino + nomeAudio[:-4] + "_tempo.wav", sinalTempo, freqAmostragem)
    
    # RETORNO OS PARAMETROS DE CADA EFEITO
    return velocidade, snr, pitch, tempo

# %% [markdown]
# ## Aumentando o dataset de treinamento

# %%
arquivosOrigem = np.array(os.listdir(diretorioOrigemTreinamento))

# RODE A LINHA ABAIXO APENAS PARA TESTES RAPIDOS
#arquivosOrigem = arquivosOrigem[:10] # TESTES RAPIDOS

resposta = Parallel(n_jobs=-1, verbose=100)(delayed(aumentarDataset)(arquivoAtual, diretorioOrigemTreinamento, diretorioDestinoTreinamento) for arquivoAtual in arquivosOrigem)
arrayVelocidades, arraySNRs, arrayPitchs, arrayTempos = zip(*resposta)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   37.2s
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:   37.2s
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   40.2s
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:   59.2s
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 478 out of 480 | elapsed:  1.6min remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed:  1.6min finished

# %% [markdown]
# ##### Salvando as distribuições de probabilidade

# %%
# ABRINDO O ARQUIVO TXT
arquivoResultados = "../resultados/dist_prob.txt"
if os.path.exists(arquivoResultados):
    os.remove(arquivoResultados)
objFile = open(arquivoResultados, "a")

# ESCREVENDO O CABECALHO
objFile.write("TREINAMENTO:")

# ESCREVENDO OS ARRAYS
objFile.write("\nSNRs: ")
for i in arraySNRs:
    objFile.write(str(i) + ", ")    
objFile.write("\nPitchs: ")
for i in arrayPitchs:
    objFile.write(str(i) + ", ")    
objFile.write("\nVelocidades: ")
for i in arrayVelocidades:
    objFile.write(str(i) + ", ")    
objFile.write("\nTempos: ")
for i in arrayTempos:
    objFile.write(str(i) + ", ")    

# FECHANDO
objFile.close()

# %%
bins = 30

plt.hist(arrayPitchs, bins, histtype="stepfilled")
plt.title("Distribuição das alterações de pitch no dataset de treinamento")
plt.grid(alpha=0.3)
plt.xlabel("Pitch Shift")
plt.savefig("../resultados/distribuicao_treinamento_pitch.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arraySNRs, bins, histtype="stepfilled")
plt.title("Distribuição das SNRs no dataset de treinamento")
plt.grid(alpha=0.3)
plt.xlabel("SNR (dB)")
plt.savefig("../resultados/distribuicao_treinamento_ruido.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arrayVelocidades, bins, histtype="stepfilled")
plt.title("Distribuição das velocidades de reprodução no dataset de treinamento")
plt.grid(alpha=0.3)
plt.xlabel("Velocidade de Reprodução")
plt.savefig("../resultados/distribuicao_treinamento_velocidade.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arrayTempos, bins, histtype="stepfilled")
plt.title("Distribuição dos percentuais de deslocamentos temporais no dataset de treinamento")
plt.grid(alpha=0.3)
plt.xlabel("Percentual de Deslocamento Temporal")
plt.savefig("../resultados/distribuicao_treinamento_tempo.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Aumentando o dataset de teste

# %%
arquivosOrigem = np.array(os.listdir(diretorioOrigemTeste))

# RODE A LINHA ABAIXO APENAS PARA TESTES RAPIDOS
#arquivosOrigem = arquivosOrigem[:10] # TESTES RAPIDOS

resposta = Parallel(n_jobs=-1, verbose=100)(delayed(aumentarDataset)(arquivoAtual, diretorioOrigemTeste, diretorioDestinoTeste) for arquivoAtual in arquivosOrigem)
arrayVelocidades, arraySNRs, arrayPitchs, arrayTempos = zip(*resposta)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 105 | elapsed:   22.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 102 out of 105 | elapsed:   23.6s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:   24.3s finished

# %% [markdown]
# ##### Salvando as distribuições de probabilidade

# %%
# ABRINDO O ARQUIVO TXT
objFile = open(arquivoResultados, "a")

# ESCREVENDO O CABECALHO
objFile.write("\n\nTESTE:")

# ESCREVENDO OS ARRAYS
objFile.write("\nSNRs: ")
for i in arraySNRs:
    objFile.write(str(i) + ", ")    
objFile.write("\nPitchs: ")
for i in arrayPitchs:
    objFile.write(str(i) + ", ")    
objFile.write("\nVelocidades: ")
for i in arrayVelocidades:
    objFile.write(str(i) + ", ")    
objFile.write("\nTempos: ")
for i in arrayTempos:
    objFile.write(str(i) + ", ")    

# FECHANDO
objFile.close()

# %%
bins = 30

plt.hist(arrayPitchs, bins, histtype="stepfilled")
plt.title("Distribuição das alterações de pitch no dataset de teste")
plt.grid(alpha=0.3)
plt.xlabel("Pitch Shift")
plt.savefig("../resultados/distribuicao_teste_pitch.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arraySNRs, bins, histtype="stepfilled")
plt.title("Distribuição das SNRs no dataset de teste")
plt.grid(alpha=0.3)
plt.xlabel("SNR (dB)")
plt.savefig("../resultados/distribuicao_teste_ruido.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arrayVelocidades, bins, histtype="stepfilled")
plt.title("Distribuição das velocidades de reprodução no dataset de teste")
plt.grid(alpha=0.3)
plt.xlabel("Velocidade de Reprodução")
plt.savefig("../resultados/distribuicao_teste_velocidade.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

plt.hist(arrayTempos, bins, histtype="stepfilled")
plt.title("Distribuição dos percentuais de deslocamentos temporais no dataset de teste")
plt.grid(alpha=0.3)
plt.xlabel("Percentual de Deslocamento Temporal")
plt.savefig("../resultados/distribuicao_teste_tempo.pdf", format='pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Função antiga que misturava os efeitos

# %% [markdown]
# Cada áudio na origem vai gerar oito áudios no destino:
#
# 1) Original
#
# 2) Com deslocamento temporal
#
# 3) Com mudança de pitch
#
# 4) Com adição de ruído branco
#
# 5) Com alteração na velocidade de reprodução
#
# 6) Com dois efeitos misturados (selecionados aleatoriamente)
#
# 7) Com três efeitos misturados (selecionados aleatoriamente)
#
# 8) Com todos os efeitos

# %%
# def aumentarDatasetTeste(nomeAudioTeste, diretorioOrigem, diretorioDestino):
    
#     # ABRINDO O AUDIO
#     sinalOriginal, freqAmostragem = librosa.core.load(diretorioOrigem + nomeAudioTeste, sr=None, mono=True)
    
#     # NORMALIZANDO PELA ENERGIA
#     sinalOriginal = efeitos.normalizarEnergia(sinalOriginal)
    
#     # APLICANDO OS EFEITOS SINGULARES
#     sinalVelocidade, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#     sinalRuido, __      = efeitos.adicionarRuidoBrancoAleatoriamente(sinalOriginal)
#     sinalPitch, __      = efeitos.mudarPitchAleatoriamente(sinalOriginal, freqAmostragem)
#     sinalTempo, __      = efeitos.deslocarTempoAleatoriamente(sinalOriginal)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_original.wav", sinalOriginal, freqAmostragem)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade.wav", sinalVelocidade, freqAmostragem)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_ruido.wav", sinalRuido, freqAmostragem)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_pitch.wav", sinalPitch, freqAmostragem)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_tempo.wav", sinalTempo, freqAmostragem)
    
#     # APLICANDO DOIS EFEITOS
#     escolha = np.random.randint(0, 6)    
#     if escolha == 0: # efeitos == [1,2]
#         print("Entrou em 0")
#         sinalDois, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalDois, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalDois)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_ruido.wav", sinalDois, freqAmostragem)
#     elif escolha == 1: # efeitos == [1,3]
#         print("Entrou em 1")
#         sinalDois, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalDois, __ = efeitos.mudarPitchAleatoriamente(sinalDois, freqAmostragem)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_pitch.wav", sinalDois, freqAmostragem)
#     elif escolha == 2: # efeitos == [1,4]
#         print("Entrou em 2")
#         sinalDois, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalDois, __ = efeitos.deslocarTempoAleatoriamente(sinalDois)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_tempo.wav", sinalDois, freqAmostragem)
#     elif escolha == 3: # efeitos == [2,3]
#         print("Entrou em 3")
#         sinalDois, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalOriginal)
#         sinalDois, __ = efeitos.mudarPitchAleatoriamente(sinalDois, freqAmostragem)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_ruido_pitch.wav", sinalDois, freqAmostragem)
#     elif escolha == 4: # efeitos == [2,4]
#         print("Entrou em 4")
#         sinalDois, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalOriginal)
#         sinalDois, __ = efeitos.deslocarTempoAleatoriamente(sinalDois)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_ruido_tempo.wav", sinalDois, freqAmostragem)
#     else: # efeitos == [3,4]
#         print("Entrou no else")
#         sinalDois, __ = efeitos.mudarPitchAleatoriamente(sinalOriginal, freqAmostragem)
#         sinalDois, __ = efeitos.deslocarTempoAleatoriamente(sinalDois)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_pitch_tempo.wav", sinalDois, freqAmostragem)
    
#     # APLICANDO TRES EFEITOS
#     escolha = np.random.randint(0, 4)
#     if escolha == 0: # efeitos == [1,2,3]
#         sinalTres, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalTres, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalTres)
#         sinalTres, __ = efeitos.mudarPitchAleatoriamente(sinalTres, freqAmostragem)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_ruido_pitch.wav", sinalTres, freqAmostragem)
#     elif escolha == 1: # efeitos == [1,2,4]
#         sinalTres, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalTres, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalTres)
#         sinalTres, __ = efeitos.deslocarTempoAleatoriamente(sinalTres)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_ruido_tempo.wav", sinalTres, freqAmostragem)
#     elif escolha == 2: # efeitos == [1,3,4]
#         sinalTres, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#         sinalTres, __ = efeitos.mudarPitchAleatoriamente(sinalTres, freqAmostragem)
#         sinalTres, __ = efeitos.deslocarTempoAleatoriamente(sinalTres)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_pitch_tempo.wav", sinalTres, freqAmostragem)
#     else: # efeitos == [2,3,4]
#         sinalTres, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalOriginal)
#         sinalTres, __ = efeitos.mudarPitchAleatoriamente(sinalTres, freqAmostragem)
#         sinalTres, __ = efeitos.deslocarTempoAleatoriamente(sinalTres)
#         librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_ruido_pitch_tempo.wav", sinalTres, freqAmostragem)
    
#     # APLICANDO TODOS OS EFEITOS
#     sinalTodos, __ = efeitos.alterarVelocidadeAleatoriamente(sinalOriginal)
#     sinalTodos, __ = efeitos.adicionarRuidoBrancoAleatoriamente(sinalTodos)
#     sinalTodos, __ = efeitos.mudarPitchAleatoriamente(sinalTodos, freqAmostragem)
#     sinalTodos, __ = efeitos.deslocarTempoAleatoriamente(sinalTodos)
#     librosa.output.write_wav(diretorioDestino + nomeAudioTeste[:-4] + "_velocidade_ruido_pitch_tempo.wav", sinalTodos, freqAmostragem)
