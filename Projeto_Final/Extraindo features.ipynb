# %% [markdown]
# # Extraindo features

# %%
from extrairFeatures import ExtrairFeatures

# %%
# DEFININDO PARAMETROS INICIAIS
pastaRaiz      = '/home/dimi/Downloads/Datasets/SESA/SESA_Aumentado_Projeto_Final_ML/train/'
freqAmostragem = 16000
frameLength    = int(0.500 * freqAmostragem) # 500 milisegundos
overlapLength  = int(frameLength / 2) # 50% de overlap
escalonamento  = True

print("Frame Length:", frameLength)
print("Overlap:", overlapLength)

# MANDANDO EXTRAIR
ExtrairFeatures(pastaRaiz, freqAmostragem, frameLength, overlapLength, escalonamento)
# Out:
# Frame Length: 8000
# Overlap: 4000
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    7.5s
# ...

# %%
# DEFININDO PARAMETROS INICIAIS
pastaRaiz      = '/home/dimi/Downloads/Datasets/SESA/SESA_Aumentado_Projeto_Final_ML/test/'
freqAmostragem = 16000
frameLength    = int(0.500 * freqAmostragem) # 500 milisegundos
overlapLength  = int(frameLength / 2) # 50% de overlap
escalonamento  = True

print("Frame Length:", frameLength)
print("Overlap:", overlapLength)

# MANDANDO EXTRAIR
ExtrairFeatures(pastaRaiz, freqAmostragem, frameLength, overlapLength, escalonamento)
# Out:
# Frame Length: 8000
# Overlap: 4000
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    6.0s
# ...
